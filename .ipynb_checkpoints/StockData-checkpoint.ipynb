# %%
import yfinance as yf
import pandas as pd
from pandas_datareader import data, wb
import numpy as np  
import datetime as datetime 
import matplotlib as plt
import seaborn as sns

# %%
#tickers = ['ORCL', 'TSLA', 'IBM']
#start = '2014-01-01'
#end = '2014-12-31'
#stockRawData = data.DataReader(tickers, 'yahoo', start, end)

# %%
#print (stockRawData)

# %%
soybeans = yf.Ticker('ZS=F')

# %%
soybeans

# %%
df_yahoo = yf.download(['FB','TSLA', 'ORCL', 'IBM', 'AAPL'],
start='2021-01-01',
end='2021-03-10',
progress=False)

# %%
df_yahoo.tail()
# Out:
#              Adj Close                                                 \
#                   AAPL          FB         IBM       ORCL        TSLA
# Date
# 2021-03-03  122.059998  255.410004  122.360001  66.910004  653.200012
# 2021-03-04  120.129997  257.640015  120.110001  65.610001  621.440002
# 2021-03-05  121.419998  264.279999  122.830002  69.970001  597.950012
# 2021-03-08  116.360001  255.309998  124.809998  72.160004  563.000000
# 2021-03-09  121.089996  265.739990  124.180000  72.639999  673.580017
#
#                  Close                                                 ...  \
#                   AAPL          FB         IBM       ORCL        TSLA  ...
# Date                                                                   ...
# 2021-03-03  122.059998  255.410004  122.360001  66.910004  653.200012  ...
# 2021-03-04  120.129997  257.640015  120.110001  65.610001  621.440002  ...
# 2021-03-05  121.419998  264.279999  122.830002  69.970001  597.950012  ...
# ...

# %%
df_yahoo1 = yf.download('AAPL',
start='2015-03-10',
end='2021-03-10',
progress=False, auto_adjust=True, actions='inline')

# %%
df_yahoo1.tail()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-03-03  124.809998  125.709999  121.839996  122.059998  112430400
# 2021-03-04  121.750000  123.599998  118.620003  120.129997  177275300
# 2021-03-05  120.980003  121.940002  117.570000  121.419998  153590400
# 2021-03-08  120.930000  121.000000  116.209999  116.360001  153918600
# 2021-03-09  119.029999  122.059998  118.790001  121.089996  129159600
#
#             Dividends  Stock Splits
# Date
# 2021-03-03        0.0           0.0
# 2021-03-04        0.0           0.0
# 2021-03-05        0.0           0.0
# 2021-03-08        0.0           0.0
# 2021-03-09        0.0           0.0

# %% [markdown]
# # Time Series Visualization

# %%
df_yahoo1['Close'].plot(figsize=(8,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_yahoo1.plot(subplots=True, figsize=(10,12))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)
