# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
import yfinance as yf
import numpy as np

# %%
Soybeans=yf.Ticker("ZS=F")
Corn=yf.Ticker("ZC=F")
Wheat=yf.Ticker("ZW=F")
Cotton=yf.Ticker("CT=F")
Crude=yf.Ticker("CL=F")
USDBRL=yf.Ticker("BRL=X")
EURUSD=yf.Ticker("EURUSD=X")
IR=yf.Ticker("^TNX")

# %%
#Soybeans_H=Soybeans.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits","Open"], axis=1)
#Soybeans_H["Range"]=Soybeans_H["High"]-Soybeans_H["Low"]
#Soybeans_H=Soybeans_H.drop(["High","Low"], axis=1)
#Soybeans_H

# %%
Soybeans_H=Soybeans.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
Soybeans_H["Range"]=Soybeans_H["High"]-Soybeans_H["Low"]
Soybeans_H=Soybeans_H.drop(["High","Low"], axis=1)
window = 90  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

Soybeans_H['log_rtn'] = np.log(Soybeans_H['Close']).diff()

# Var Swap (returns are not demeaned)
Soybeans_H['real_var'] = np.square(Soybeans_H['log_rtn']).rolling(window).sum() * ann_factor
Soybeans_H['real_vol'] = np.sqrt(Soybeans_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

Soybeans_H=Soybeans_H.sort_values(by="Date", ascending=False).dropna()
Soybeans_H
# Out:
#               Close  Volume  Range   log_rtn  real_var  real_vol
# Date
# 2021-03-12  1413.00   96945  25.50 -0.001944  0.043320  0.208135
# 2021-03-12  1415.75     180  29.25  0.000177  0.043386  0.208293
# 2021-03-11  1415.50     180  14.00  0.002830  0.044915  0.211932
# 2021-03-10  1411.50     340  30.25 -0.020858  0.044965  0.212049
# 2021-03-09  1441.25     186  13.50  0.002431  0.043785  0.209248
# ...             ...     ...    ...       ...       ...       ...
# 2001-01-31   459.75     119   1.25 -0.003257  0.028876  0.169929
# 2001-01-30   461.25      76   1.50  0.003257  0.028972  0.170212
# 2001-01-29   459.75     259   2.25 -0.015646  0.028954  0.170160
# 2001-01-26   467.00     146   2.00 -0.004274  0.028270  0.168136
# 2001-01-25   469.00     193   1.00  0.002134  0.029332  0.171267
#
# [5032 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-b347d5e356ac> in <module>
# ----> 1 index(Soybeans_H)
#
# NameError: name 'index' is not defined

# %%
plt.plot(Soybeans_H["Close"])
plt.show()

# %%
Corn_H=Corn.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
Corn_H["Range"]=Corn_H["High"]-Corn_H["Low"]
Corn_H=Corn_H.drop(["High","Low"], axis=1)
window = 90  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

Corn_H['log_rtn'] = np.log(Corn_H['Close']).diff()

# Var Swap (returns are not demeaned)
Corn_H['real_var'] = np.square(Corn_H['log_rtn']).rolling(window).sum() * ann_factor
Corn_H['real_vol'] = np.sqrt(Corn_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

Corn_H=Corn_H.sort_values(by="Date", ascending=False).dropna()
Corn_H
# Out:
#              Close  Volume  Range   log_rtn  real_var  real_vol
# Date
# 2021-03-12  539.75  116281   9.50 -0.017448  0.062632  0.250263
# 2021-03-12  549.25     672   7.00 -0.010414  0.061937  0.248871
# 2021-03-11  555.00     672   9.25  0.013149  0.065157  0.255259
# 2021-03-10  547.75    1986  17.00 -0.025683  0.064723  0.254406
# 2021-03-09  562.00    2224  10.75 -0.005324  0.062912  0.250822
# ...            ...     ...    ...       ...       ...       ...
# 2000-12-26  220.00     501   1.00  0.009132  0.033579  0.183245
# 2000-12-21  218.00     773   0.00  0.011534  0.033591  0.183278
# 2000-12-18  215.50       1   0.00  0.025853  0.034542  0.185854
# 2000-12-04  210.00       3   0.00  0.004773  0.032803  0.181116
# 2000-12-01  209.00       1   0.75  0.019324  0.032934  0.181477
#
# [5040 rows x 6 columns]

# %%
plt.plot(Corn_H["Close"])
plt.plot(Soybeans_H["Close"])
plt.show()

# %%
Wheat_H=Wheat.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits","Open"], axis=1)
Wheat_H["Range"]=Wheat_H["High"]-Wheat_H["Low"]
Wheat_H=Wheat_H.drop(["High","Low"], axis=1)

# %%
Cotton_H=Cotton.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits","Open"], axis=1)
Cotton_H["Range"]=Cotton_H["High"]-Cotton_H["Low"]
Cotton_H=Cotton_H.drop(["High","Low"], axis=1)

# %%
Crude_H=Crude.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
Crude_H["Range"]=Crude_H["High"]-Crude_H["Low"]
Crude_H=Crude_H.drop(["High","Low"], axis=1)
window = 90  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

Crude_H['log_rtn'] = np.log(Crude_H['Close']).diff()

# Var Swap (returns are not demeaned)
Crude_H['real_var'] = np.square(Crude_H['log_rtn']).rolling(window).sum() * ann_factor
Crude_H['real_vol'] = np.sqrt(Crude_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

Crude_H=Crude_H.sort_values(by="Date", ascending=False).dropna()
Crude_H
# Out:
# C:\Users\dorit\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                 Close  Volume     Range   log_rtn  real_var  real_vol
# Date
# 2021-03-14  66.050003    4419  0.620003  0.006684  0.105782  0.325242
# 2021-03-12  65.610001  441063  0.829994 -0.006230  0.108738  0.329755
# 2021-03-11  66.019997  441063  1.669998  0.024223  0.117621  0.342960
# 2021-03-10  64.440002  498488  1.829998  0.006695  0.117850  0.343293
# 2021-03-09  64.010002  554564  2.350002 -0.016117  0.120757  0.347501
# ...               ...     ...       ...       ...       ...       ...
# 2001-01-09  27.719999   69916  0.850000  0.013438  0.230909  0.480530
# 2001-01-08  27.350000   76058  1.250000 -0.023488  0.230462  0.480065
# 2001-01-05  28.000000   63852  1.000000 -0.007117  0.230705  0.480317
# 2001-01-04  28.200001   74383  0.930000  0.008905  0.231050  0.480676
# 2001-01-03  27.950001   66628  1.090000  0.027200  0.231315  0.480952
#
# [4948 rows x 6 columns]

# %%
fig,ax=plt.subplots()
ax.plot(Crude_H["Close"])
ax2=ax.twinx()
ax2.plot(Soybeans_H["Close"], color="red")

plt.show()

# %%
USDBRL_H=USDBRL.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits","Open"], axis=1)
USDBRL_H["Range"]=USDBRL_H["High"]-USDBRL_H["Low"]
USDBRL_H=USDBRL_H.drop(["High","Low"], axis=1)

# %%
EURUSD_H=EURUSD.history(period="Max").sort_values(by="Date", ascending=False).drop(["Dividends", "Stock Splits","Open"], axis=1)
EURUSD_H=EURUSD.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
EURUSD_H["Range"]=EURUSD_H["High"]-EURUSD_H["Low"]
EURUSD_H=EURUSD_H.drop(["High","Low"], axis=1)
window = 90  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

EURUSD_H['log_rtn'] = np.log(EURUSD_H['Close']).diff()

# Var Swap (returns are not demeaned)
EURUSD_H['real_var'] = np.square(EURUSD_H['log_rtn']).rolling(window).sum() * ann_factor
EURUSD_H['real_vol'] = np.sqrt(EURUSD_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

EURUSD_H=EURUSD_H.sort_values(by="Date", ascending=False).dropna()[:len(Soybeans_H)]
EURUSD_H
# Out:
#                Close  Volume     Range   log_rtn  real_var  real_vol
# Date
# 2021-03-12  1.198610       0  0.007983  0.005022  0.003539  0.059487
# 2021-03-11  1.192606       0  0.006066  0.002363  0.003614  0.060113
# 2021-03-10  1.189791       0  0.005506  0.003890  0.003616  0.060130
# 2021-03-09  1.185171       0  0.007986 -0.006218  0.003865  0.062167
# 2021-03-08  1.192563       0  0.008384 -0.003524  0.003757  0.061290
# ...              ...     ...       ...       ...       ...       ...
# 2004-04-09  1.208605       0  0.004604  0.000749  0.015205  0.123308
# 2004-04-08  1.207700       0  0.015008 -0.007346  0.015417  0.124165
# 2004-04-07  1.216604       0  0.013900  0.002879  0.015300  0.123692
# 2004-04-06  1.213106       0  0.015698  0.009778  0.015299  0.123687
# 2004-04-05  1.201302       0  0.013608 -0.009608  0.015328  0.123808
#
# [4371 rows x 6 columns]

# %%
IR_H=IR.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
IR_H=IR.history(period="Max").drop(["Dividends", "Stock Splits","Open"], axis=1)
IR_H["Range"]=IR_H["High"]-IR_H["Low"]
IR_H=IR_H.drop(["High","Low"], axis=1)
window = 90  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

IR_H['log_rtn'] = np.log(IR_H['Close']).diff()

# Var Swap (returns are not demeaned)
IR_H['real_var'] = np.square(IR_H['log_rtn']).rolling(window).sum() * ann_factor
IR_H['real_vol'] = np.sqrt(IR_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

IR_H=IR_H.sort_values(by="Date", ascending=False).dropna()[:len(Soybeans_H)]
IR_H
# Out:
#             Close  Volume  Range   log_rtn  real_var  real_vol
# Date
# 2021-03-12  1.635       0  0.058  0.068338  0.412884  0.642561
# 2021-03-11  1.527       0  0.050  0.004595  0.399849  0.632336
# 2021-03-10  1.520       0  0.057 -0.016961  0.402167  0.634166
# 2021-03-09  1.546       0  0.035 -0.031830  0.408011  0.638757
# 2021-03-08  1.596       0  0.029  0.026668  0.405366  0.636684
# ...           ...     ...    ...       ...       ...       ...
# 2001-01-19  5.174       0  0.083  0.015386  0.027629  0.166220
# 2001-01-18  5.095       0  0.106 -0.011901  0.027064  0.164513
# 2001-01-17  5.156       0  0.354 -0.015015  0.026721  0.163466
# 2001-01-16  5.234       0  0.061  0.000765  0.026206  0.161884
# 2001-01-12  5.230       0  0.102  0.022038  0.026277  0.162103
#
# [5032 rows x 6 columns]

# %%
fig,ax=plt.subplots()
ax.plot(IR_H["Close"])
ax2=ax.twinx()
ax2.plot(Soybeans_H["Close"], color="red")

plt.show()

# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt

host = host_subplot(111, axes_class=AA.Axes)
plt.subplots_adjust(right=0.75)

par1 = host.twinx()
par2 = host.twinx()

offset = 60
new_fixed_axis = par2.get_grid_helper().new_fixed_axis
par2.axis["right"] = new_fixed_axis(loc="right", axes=par2,
                                        offset=(offset, 0))

par2.axis["right"].toggle(all=True)



#host.set_xlabel("Distance")
#host.set_ylabel("Density")
#par1.set_ylabel("Temperature")
#par2.set_ylabel("Velocity")

p1, = host.plot(Soybeans_H["Close"], label="Soybeans")
p2, = par1.plot(EURUSD_H["Close"], label="EURUSD")
p3, = par2.plot(IR_H["Close"], label="IR")

#par1.set_ylim(0, 4)
#par2.set_ylim(1, 65)

host.legend()

host.axis["left"].label.set_color(p1.get_color())
par1.axis["right"].label.set_color(p2.get_color())
par2.axis["right"].label.set_color(p3.get_color())

plt.draw()
plt.show()

# %%
Soybeans_H=Soybeans_H.rename(columns={"Range": "Soybeans Range", "Close": "Soybeans Close", "Volume" : "Soybeans Volume"})[:len(USDBRL_H)]
Corn_H=Corn_H.rename(columns={"Range": "Corn Range", "Close": "Corn Close", "Volume" : "Corn Volume"})[:len(USDBRL_H)]

Wheat_H=Wheat_H.rename(columns={"Range": "Wheat Range", "Close": "Wheat Close", "Volume" : "Wheat Volume"})[:len(USDBRL_H)]
Cotton_H=Cotton_H.rename(columns={"Range": "Cotton Range","Close": "Cotton Close", "Volume" : "Cotton Volume"})[:len(USDBRL_H)]
Crude_H=Crude_H.rename(columns={"Range": "Crude Range","Close": "Crude Close", "Volume" : "Crude Volume"})[:len(USDBRL_H)]
USDBRL_H=USDBRL_H.rename(columns={"Range": "USDBRL Range", "Close": "USDBRL Close", "Volume" : "USDBRL Volume"})[:len(USDBRL_H)]
EURUSD_H=EURUSD_H.rename(columns={"Range": "EURUSD Range", "Close": "EURUSD Close", "Volume" : "EURUSD Volume"})[:len(USDBRL_H)]
IR_H=IR_H.rename(columns={"Range": "IR Range", "Close": "IR Close", "Volume" : "IR Volume"})[:len(USDBRL_H)]

# %%
IR_H
# Out:
#             IR Close  IR Volume  IR Range
# Date
# 2021-03-12     1.635          0     0.058
# 2021-03-11     1.527          0     0.050
# 2021-03-10     1.520          0     0.057
# 2021-03-09     1.546          0     0.035
# 2021-03-08     1.596          0     0.029
# ...              ...        ...       ...
# 2004-12-31     4.216          0     0.027
# 2004-12-30     4.263          0     0.068
# 2004-12-29     4.322          0     0.050
# 2004-12-28     4.291          0     0.057
# 2004-12-27     4.291          0     0.073
#
# [4043 rows x 3 columns]

# %%
window = 3  # trading days in rolling window
dpy = 252  # trading days per year
ann_factor = dpy / window

IR_H['log_rtn'] = np.log(IR_H['IR Close']).diff()

# Var Swap (returns are not demeaned)
IR_H['real_var'] = np.square(IR_H['log_rtn']).rolling(window).sum() * ann_factor
IR_H['real_vol'] = np.sqrt(IR_H['real_var'])

# Classical (returns are demeaned, dof=1)
#df['real_var'] = df['log_rtn'].rolling(window).var() * ann_factor
#df['real_vol'] = np.sqrt(df['real_var'])

IR_H
# Out:
#             IR Close  IR Volume  IR Range   log_rtn  real_var  real_vol
# Date
# 2021-03-12     1.635          0     0.058       NaN       NaN       NaN
# 2021-03-11     1.527          0     0.050 -0.068338       NaN       NaN
# 2021-03-10     1.520          0     0.057 -0.004595       NaN       NaN
# 2021-03-09     1.546          0     0.035  0.016961  0.418222  0.646701
# 2021-03-08     1.596          0     0.029  0.031830  0.111039  0.333225
# ...              ...        ...       ...       ...       ...       ...
# 2004-12-31     4.216          0     0.027 -0.000948  0.018686  0.136698
# 2004-12-30     4.263          0     0.068  0.011086  0.028845  0.169839
# 2004-12-29     4.322          0     0.050  0.013745  0.026270  0.162079
# 2004-12-28     4.291          0     0.057 -0.007198  0.030547  0.174777
# 2004-12-27     4.291          0     0.073  0.000000  0.020223  0.142207
#
# [4043 rows x 6 columns]

# %%
#d={}
Prices = [Corn_H, Wheat_H, Cotton_H, Crude_H, USDBRL_H, EURUSD_H, IR_H]
#for price in Prices:
    #d[price]= price.history(period="Max")

# %%
#d[Corn].sort_values(by="Date", ascending=False)
#for price in Prices:
    #price.sort_values(by="Date", ascending=False)

# %%
for price in Prices:
    print (price.shape)
# Out:
# (4041, 3)
# (4041, 3)
# (4041, 3)
# (4041, 3)
# (4041, 3)
# (4041, 3)
# (4041, 3)

# %%
for price in Prices:
    Soybeans_H=Soybeans_H.merge(price, on="Date")

# %%
AllData=Soybeans_H
AllData
# Out:
#             Soybeans Close  Soybeans Volume  Soybeans Range  Corn Close  \
# Date
# 2021-03-10         1420.00            93846           37.25      537.00
# 2021-03-09         1441.25              149           13.50      562.00
# 2021-03-08         1437.75              149           17.50      565.00
# 2021-03-05         1434.25              171           23.00      562.00
# 2021-03-04         1415.25              385           31.50      546.25
# ...                    ...              ...             ...         ...
# 2006-03-30          587.75              988            2.50      227.75
# 2006-03-29          582.50              607            3.00      224.25
# 2006-03-28          581.50              882            2.75      222.25
# 2006-03-27          579.50              667            6.50      221.75
# 2006-03-24          573.75             4458            2.50      218.75
#
#             Corn Volume  Corn Range  Wheat Close  Wheat Volume  Wheat Range  \
# Date
# 2021-03-10       114274       14.50       650.00         31756        15.50
# 2021-03-09         2320       10.75       656.50           351         5.75
# 2021-03-08         2320       14.25       646.50           351        17.00
# 2021-03-05         1441       20.25       654.00           401        10.50
# 2021-03-04         2129        8.25       649.75           576         9.25
# ...                 ...         ...          ...           ...          ...
# 2006-03-30         2082        1.00       344.50          1139         1.50
# 2006-03-29          716        1.25       341.75           531         2.00
# 2006-03-28         1944        1.75       341.25           539         1.50
# 2006-03-27         1054        3.00       339.75           461         3.75
# 2006-03-24        12515        1.00       342.50          4122         1.50
#
#             Cotton Close  ...  Crude Range  USDBRL Close  USDBRL Volume  \
# Date                      ...
# 2021-03-10     85.930000  ...     1.829998        5.6845              0
# 2021-03-09     82.769997  ...     2.350002        5.8746              0
# 2021-03-08     86.769997  ...     3.410004        5.6895              0
# 2021-03-05     86.209999  ...     2.599998        5.6683              0
# 2021-03-04     85.589996  ...     4.340000        5.6175              0
# ...                  ...  ...          ...           ...            ...
# 2006-03-30     53.700001  ...     1.250000        2.1922              0
# 2006-03-29     53.160000  ...     1.119995        2.2206              0
# 2006-03-28     52.910000  ...     2.149994        2.1677              0
# 2006-03-27     53.099998  ...     1.100002        2.1503              0
# 2006-03-24     52.500000  ...     1.349998        2.1547              0
#
#             USDBRL Range  EURUSD Close  EURUSD Volume  EURUSD Range  IR Close  \
# Date
# 2021-03-10      0.157400      1.190760              0      0.005523     1.525
# 2021-03-09      0.078000      1.185171              0      0.007986     1.546
# 2021-03-08      0.106805      1.192563              0      0.008384     1.596
# 2021-03-05      0.059938      1.196774              0      0.007063     1.554
# 2021-03-04      0.090300      1.205066              0      0.003899     1.550
# ...                  ...           ...            ...           ...       ...
# 2006-03-30      0.025000      1.216797              0      0.014789     4.855
# 2006-03-29      0.007400      1.203094              0      0.006398     4.810
# 2006-03-28      0.001300      1.201100              0      0.010702     4.778
# 2006-03-27      0.005500      1.201100              0      0.005111     4.701
# 2006-03-24      0.012400      1.203500              0      0.009104     4.675
#
#             IR Volume  IR Range
# Date
# 2021-03-10          0     0.042
# 2021-03-09          0     0.035
# 2021-03-08          0     0.029
# 2021-03-05          0     0.086
# 2021-03-04          0     0.097
# ...               ...       ...
# 2006-03-30          0     0.078
# 2006-03-29          0     0.046
# 2006-03-28          0     0.077
# 2006-03-27          0     0.040
# 2006-03-24          0     0.084
#
# [3672 rows x 24 columns]

# %%
import json
import os
import pymongo
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/Group_Project")
db=client.Group_Project

# %%
records=json.loads(AllData.T.to_json()).values()
db.myCollection.insert(records)
# Out:
# C:\Users\dorit\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#  ObjectId('60490bcf4101eb2497480a69'),
#  ObjectId('60490bcf4101eb2497480a6a'),
#  ObjectId('60490bcf4101eb2497480a6b'),
#  ObjectId('60490bcf4101eb2497480a6c'),
#  ...]

# %%
data=db.myCollection
data.count_documents({})
# Out:
# 3672

# %%
test=pd.DataFrame(list(data.find())).drop("_id", axis=1)
test
# Out:
#       Soybeans Close  Soybeans Volume  Soybeans Range  Corn Close  \
# 0            1420.00          93846.0           37.25      537.00
# 1            1441.25            149.0           13.50      562.00
# 2            1437.75            149.0           17.50      565.00
# 3            1434.25            171.0           23.00      562.00
# 4            1415.25            385.0           31.50      546.25
# ...              ...              ...             ...         ...
# 3667          587.75            988.0            2.50      227.75
# 3668          582.50            607.0            3.00      224.25
# 3669          581.50            882.0            2.75      222.25
# 3670          579.50            667.0            6.50      221.75
# 3671          573.75           4458.0            2.50      218.75
#
#       Corn Volume  Corn Range  Wheat Close  Wheat Volume  Wheat Range  \
# 0        114274.0       14.50       650.00       31756.0        15.50
# 1          2320.0       10.75       656.50         351.0         5.75
# 2          2320.0       14.25       646.50         351.0        17.00
# 3          1441.0       20.25       654.00         401.0        10.50
# 4          2129.0        8.25       649.75         576.0         9.25
# ...           ...         ...          ...           ...          ...
# 3667       2082.0        1.00       344.50        1139.0         1.50
# 3668        716.0        1.25       341.75         531.0         2.00
# 3669       1944.0        1.75       341.25         539.0         1.50
# 3670       1054.0        3.00       339.75         461.0         3.75
# 3671      12515.0        1.00       342.50        4122.0         1.50
#
#       Cotton Close  ...  Crude Range  USDBRL Close  USDBRL Volume  \
# 0        85.930000  ...     1.829998        5.6845            0.0
# 1        82.769997  ...     2.350002        5.8746            0.0
# 2        86.769997  ...     3.410004        5.6895            0.0
# 3        86.209999  ...     2.599998        5.6683            0.0
# 4        85.589996  ...     4.340000        5.6175            0.0
# ...            ...  ...          ...           ...            ...
# 3667     53.700001  ...     1.250000        2.1922            0.0
# 3668     53.160000  ...     1.119995        2.2206            0.0
# 3669     52.910000  ...     2.149994        2.1677            0.0
# 3670     53.099998  ...     1.100002        2.1503            0.0
# 3671     52.500000  ...     1.349998        2.1547            0.0
#
#       USDBRL Range  EURUSD Close  EURUSD Volume  EURUSD Range  IR Close  \
# 0         0.157400      1.190760            0.0      0.005523     1.525
# 1         0.078000      1.185171            0.0      0.007986     1.546
# 2         0.106805      1.192563            0.0      0.008384     1.596
# 3         0.059938      1.196774            0.0      0.007063     1.554
# 4         0.090300      1.205066            0.0      0.003899     1.550
# ...            ...           ...            ...           ...       ...
# 3667      0.025000      1.216797            0.0      0.014789     4.855
# 3668      0.007400      1.203094            0.0      0.006398     4.810
# 3669      0.001300      1.201100            0.0      0.010702     4.778
# 3670      0.005500      1.201100            0.0      0.005111     4.701
# 3671      0.012400      1.203500            0.0      0.009104     4.675
#
#       IR Volume  IR Range
# 0           0.0     0.042
# 1           0.0     0.035
# 2           0.0     0.029
# 3           0.0     0.086
# 4           0.0     0.097
# ...         ...       ...
# 3667        0.0     0.078
# 3668        0.0     0.046
# 3669        0.0     0.077
# 3670        0.0     0.040
# 3671        0.0     0.084
#
# [3672 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.datasets import make_blobs
import pandas as pd
import tensorflow as tf
import matplotlib as plt

# %%
# Split our preprocessed data into our features and target arrays
X = test.drop("Soybeans Close", axis= 1)
y = test["Soybeans Close"]

# %%
X
# Out:
#       Soybeans Volume  Soybeans Range  Corn Close  Corn Volume  Corn Range  \
# 0             93846.0           37.25      537.00     114274.0       14.50
# 1               149.0           13.50      562.00       2320.0       10.75
# 2               149.0           17.50      565.00       2320.0       14.25
# 3               171.0           23.00      562.00       1441.0       20.25
# 4               385.0           31.50      546.25       2129.0        8.25
# ...               ...             ...         ...          ...         ...
# 3667            988.0            2.50      227.75       2082.0        1.00
# 3668            607.0            3.00      224.25        716.0        1.25
# 3669            882.0            2.75      222.25       1944.0        1.75
# 3670            667.0            6.50      221.75       1054.0        3.00
# 3671           4458.0            2.50      218.75      12515.0        1.00
#
#       Wheat Close  Wheat Volume  Wheat Range  Cotton Close  Cotton Volume  \
# 0          650.00       31756.0        15.50     85.930000        17153.0
# 1          656.50         351.0         5.75     82.769997            0.0
# 2          646.50         351.0        17.00     86.769997            0.0
# 3          654.00         401.0        10.50     86.209999            0.0
# 4          649.75         576.0         9.25     85.589996            0.0
# ...           ...           ...          ...           ...            ...
# 3667       344.50        1139.0         1.50     53.700001        21899.0
# 3668       341.75         531.0         2.00     53.160000         9321.0
# 3669       341.25         539.0         1.50     52.910000         6812.0
# 3670       339.75         461.0         3.75     53.099998         9395.0
# 3671       342.50        4122.0         1.50     52.500000         5374.0
#
#       ...  Crude Range  USDBRL Close  USDBRL Volume  USDBRL Range  \
# 0     ...     1.829998        5.6845            0.0      0.157400
# 1     ...     2.350002        5.8746            0.0      0.078000
# 2     ...     3.410004        5.6895            0.0      0.106805
# 3     ...     2.599998        5.6683            0.0      0.059938
# 4     ...     4.340000        5.6175            0.0      0.090300
# ...   ...          ...           ...            ...           ...
# 3667  ...     1.250000        2.1922            0.0      0.025000
# 3668  ...     1.119995        2.2206            0.0      0.007400
# 3669  ...     2.149994        2.1677            0.0      0.001300
# 3670  ...     1.100002        2.1503            0.0      0.005500
# 3671  ...     1.349998        2.1547            0.0      0.012400
#
#       EURUSD Close  EURUSD Volume  EURUSD Range  IR Close  IR Volume  IR Range
# 0         1.190760            0.0      0.005523     1.525        0.0     0.042
# 1         1.185171            0.0      0.007986     1.546        0.0     0.035
# 2         1.192563            0.0      0.008384     1.596        0.0     0.029
# 3         1.196774            0.0      0.007063     1.554        0.0     0.086
# 4         1.205066            0.0      0.003899     1.550        0.0     0.097
# ...            ...            ...           ...       ...        ...       ...
# 3667      1.216797            0.0      0.014789     4.855        0.0     0.078
# 3668      1.203094            0.0      0.006398     4.810        0.0     0.046
# 3669      1.201100            0.0      0.010702     4.778        0.0     0.077
# 3670      1.201100            0.0      0.005111     4.701        0.0     0.040
# 3671      1.203500            0.0      0.009104     4.675        0.0     0.084
#
# [3672 rows x 23 columns]
